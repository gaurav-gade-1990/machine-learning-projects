# %%
# Code using keras
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
from keras import initializers

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %%
# Load dataset
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
plt.figure()
plt.imshow(train_images[2])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
num_pixels = train_images.shape[1] * train_images.shape[2]   #28*28 = 784
X_train = train_images.reshape(train_images.shape[0], num_pixels)
X_test = test_images.reshape(test_images.shape[0], num_pixels)

# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255


Y_test = test_labels 
from keras.utils import np_utils
# one hot encode outputs
y_train = np_utils.to_categorical(train_labels )
y_test = np_utils.to_categorical(test_labels )


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers
import tensorflow as tf



hidden_nodes = 128
num_classes = y_test.shape[1]

# %% [markdown]
# *** Building the model with SGD optimizer.

# %%
#tf.random.normal(shape=(hidden_nodes,num_pixels)
def baseline_model():
    # create model
    model = Sequential()
    #model.add(Dense(hidden_nodes, input_dim= num_pixels, kernel_initializer='normal', activation='relu'))
    #model.add(Dense(hidden_nodes, kernel_initializer='normal', activation='relu'))
    #model.add(Dense(num_classes,  kernel_initializer='normal',activation='softmax'))
    model.add(Dense(hidden_nodes, input_dim= num_pixels, kernel_initializer='normal', activation='relu'))
    model.add(Dense(hidden_nodes, kernel_initializer='normal', activation='relu'))
    model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
    sgd = optimizers.SGD(lr=0.01, momentum=0.0, decay= 0.00)
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    return model

# %%
model = baseline_model()
# Fit the model
final_model = model.fit(X_train, y_train, validation_split=0.2, epochs=55, batch_size=128)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose= 0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/55
# 375/375 [==============================] - 3s 7ms/step - loss: 1.8794 - accuracy: 0.4321 - val_loss: 1.2972 - val_accuracy: 0.6450
# Epoch 2/55
# 375/375 [==============================] - 2s 6ms/step - loss: 1.0342 - accuracy: 0.6635 - val_loss: 0.8577 - val_accuracy: 0.7048
# Epoch 3/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.7970 - accuracy: 0.7175 - val_loss: 0.7325 - val_accuracy: 0.7314
# Epoch 4/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.7024 - accuracy: 0.7529 - val_loss: 0.6596 - val_accuracy: 0.7763
# Epoch 5/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.6411 - accuracy: 0.7805 - val_loss: 0.6093 - val_accuracy: 0.7883411 - accuracy: 0.
# Epoch 6/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5975 - accuracy: 0.7953 - val_loss: 0.5740 - val_accuracy: 0.8023
# Epoch 7/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5649 - accuracy: 0.8068 - val_loss: 0.5467 - val_accuracy: 0.8123
# Epoch 8/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.5395 - accuracy: 0.8149 - val_loss: 0.5284 - val_accuracy: 0.8167
# Epoch 9/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.5210 - accuracy: 0.8210 - val_loss: 0.5177 - val_accuracy: 0.8194
# Epoch 10/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.5050 - accuracy: 0.8248 - val_loss: 0.4980 - val_accuracy: 0.8268
# Epoch 11/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4925 - accuracy: 0.8290 - val_loss: 0.5099 - val_accuracy: 0.8173
# Epoch 12/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4834 - accuracy: 0.8320 - val_loss: 0.4800 - val_accuracy: 0.8292
# Epoch 13/55
# 375/375 [==============================] - 3s 8ms/step - loss: 0.4726 - accuracy: 0.8358 - val_loss: 0.4716 - val_accuracy: 0.8324
# Epoch 14/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4651 - accuracy: 0.8379 - val_loss: 0.4644 - val_accuracy: 0.8359
# Epoch 15/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4592 - accuracy: 0.8420 - val_loss: 0.4645 - val_accuracy: 0.8379
# Epoch 16/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4535 - accuracy: 0.8424 - val_loss: 0.4554 - val_accuracy: 0.8380
# Epoch 17/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4474 - accuracy: 0.8452 - val_loss: 0.4501 - val_accuracy: 0.8422
# Epoch 18/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4412 - accuracy: 0.8468 - val_loss: 0.4445 - val_accuracy: 0.8450
# Epoch 19/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4358 - accuracy: 0.8484 - val_loss: 0.4785 - val_accuracy: 0.8248
# Epoch 20/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4321 - accuracy: 0.8504 - val_loss: 0.4392 - val_accuracy: 0.8459
# Epoch 21/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4270 - accuracy: 0.8514 - val_loss: 0.4387 - val_accuracy: 0.8438
# Epoch 22/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4231 - accuracy: 0.8522 - val_loss: 0.4301 - val_accuracy: 0.8492
# Epoch 23/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4202 - accuracy: 0.8533 - val_loss: 0.4313 - val_accuracy: 0.8504
# Epoch 24/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4152 - accuracy: 0.8554 - val_loss: 0.4232 - val_accuracy: 0.8515
# Epoch 25/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4115 - accuracy: 0.8576 - val_loss: 0.4304 - val_accuracy: 0.8471
# Epoch 26/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4082 - accuracy: 0.8589 - val_loss: 0.4211 - val_accuracy: 0.8527
# Epoch 27/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4044 - accuracy: 0.8590 - val_loss: 0.4267 - val_accuracy: 0.8508
# Epoch 28/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.4009 - accuracy: 0.8609 - val_loss: 0.4161 - val_accuracy: 0.8538
# Epoch 29/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3980 - accuracy: 0.8620 - val_loss: 0.4078 - val_accuracy: 0.8590
# Epoch 30/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3942 - accuracy: 0.8630 - val_loss: 0.4067 - val_accuracy: 0.8584
# Epoch 31/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3909 - accuracy: 0.8637 - val_loss: 0.4121 - val_accuracy: 0.8583
# Epoch 32/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3880 - accuracy: 0.8662 - val_loss: 0.4131 - val_accuracy: 0.8552
# Epoch 33/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3860 - accuracy: 0.8653 - val_loss: 0.3989 - val_accuracy: 0.8608
# Epoch 34/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3827 - accuracy: 0.8662 - val_loss: 0.4004 - val_accuracy: 0.8614
# Epoch 35/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3810 - accuracy: 0.8666 - val_loss: 0.4019 - val_accuracy: 0.8602
# Epoch 36/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3773 - accuracy: 0.8688 - val_loss: 0.3950 - val_accuracy: 0.8627
# Epoch 37/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3756 - accuracy: 0.8689 - val_loss: 0.3946 - val_accuracy: 0.8611
# Epoch 38/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3729 - accuracy: 0.8696 - val_loss: 0.3917 - val_accuracy: 0.8631
# Epoch 39/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3720 - accuracy: 0.8694 - val_loss: 0.3885 - val_accuracy: 0.8643
# Epoch 40/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3672 - accuracy: 0.8714 - val_loss: 0.3882 - val_accuracy: 0.8643
# Epoch 41/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3655 - accuracy: 0.8724 - val_loss: 0.3882 - val_accuracy: 0.8652
# Epoch 42/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3627 - accuracy: 0.8741 - val_loss: 0.3820 - val_accuracy: 0.8669
# Epoch 43/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3607 - accuracy: 0.8745 - val_loss: 0.3829 - val_accuracy: 0.8672
# Epoch 44/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3595 - accuracy: 0.8743 - val_loss: 0.3824 - val_accuracy: 0.8662
# Epoch 45/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3568 - accuracy: 0.8746 - val_loss: 0.3797 - val_accuracy: 0.8681
# Epoch 46/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3544 - accuracy: 0.8760 - val_loss: 0.3823 - val_accuracy: 0.8650
# Epoch 47/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3522 - accuracy: 0.8763 - val_loss: 0.3789 - val_accuracy: 0.8665
# Epoch 48/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3500 - accuracy: 0.8771 - val_loss: 0.3800 - val_accuracy: 0.8687
# Epoch 49/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3479 - accuracy: 0.8777 - val_loss: 0.3793 - val_accuracy: 0.8692
# Epoch 50/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3467 - accuracy: 0.8780 - val_loss: 0.3704 - val_accuracy: 0.8710
# Epoch 51/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3436 - accuracy: 0.8800 - val_loss: 0.3769 - val_accuracy: 0.8677
# Epoch 52/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3424 - accuracy: 0.8799 - val_loss: 0.3828 - val_accuracy: 0.8660
# Epoch 53/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3405 - accuracy: 0.8794 - val_loss: 0.3697 - val_accuracy: 0.8713
# Epoch 54/55
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3391 - accuracy: 0.8800 - val_loss: 0.3658 - val_accuracy: 0.8718
# Epoch 55/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3361 - accuracy: 0.8806 - val_loss: 0.3688 - val_accuracy: 0.8732
# Accuracy: 86.33%

# %%
predictions = model.predict(X_test)
predictions[0]
# Out:
# array([2.5684460e-05, 2.4108556e-07, 4.6406135e-06, 1.3987863e-06,
#        3.6286687e-07, 4.5961037e-02, 1.1378208e-05, 5.8310598e-02,
#        1.7060277e-03, 8.9397860e-01], dtype=float32)

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
  
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
  
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1]) 
    predicted_label = np.argmax(predictions_array)
 
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, Y_test, test_images)
plt.show()
plt.subplot(1,2,2)
plot_value_array(i, predictions,  Y_test)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(final_model.history['accuracy'])
plt.plot(final_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(final_model.history['loss'])
plt.plot(final_model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.show()

# %% [markdown]
# Now optimizing with Adam optimizer.

# %%
#tf.random.normal(shape=(hidden_nodes,num_pixels)
def baseline_model():
    # create model
    model = Sequential()
    #model.add(Dense(hidden_nodes, input_dim= num_pixels, kernel_initializer='normal', activation='relu'))
    #model.add(Dense(hidden_nodes, kernel_initializer='normal', activation='relu'))
    #model.add(Dense(num_classes,  kernel_initializer='normal',activation='softmax'))
    model.add(Dense(hidden_nodes, input_dim= num_pixels, kernel_initializer='normal', activation='relu'))
    model.add(Dense(hidden_nodes, kernel_initializer='normal', activation='relu'))
    model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
    sgd = optimizers.SGD(lr=0.01, momentum=0.0, decay= 0.00)
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = baseline_model()
# Fit the model
final_model = model.fit(X_train, y_train, validation_split=0.2, epochs=55, batch_size=128)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose= 0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/55
# 375/375 [==============================] - 4s 10ms/step - loss: 0.6305 - accuracy: 0.7778 - val_loss: 0.4794 - val_accuracy: 0.8304
# Epoch 2/55
# 375/375 [==============================] - 3s 8ms/step - loss: 0.4133 - accuracy: 0.8532 - val_loss: 0.3938 - val_accuracy: 0.8618
# Epoch 3/55
# 375/375 [==============================] - 3s 8ms/step - loss: 0.3693 - accuracy: 0.8690 - val_loss: 0.3648 - val_accuracy: 0.8678
# Epoch 4/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.3359 - accuracy: 0.8773 - val_loss: 0.3389 - val_accuracy: 0.8786
# Epoch 5/55
# 375/375 [==============================] - 3s 8ms/step - loss: 0.3136 - accuracy: 0.8863 - val_loss: 0.3411 - val_accuracy: 0.8805
# Epoch 6/55
# 375/375 [==============================] - 3s 8ms/step - loss: 0.3011 - accuracy: 0.8886 - val_loss: 0.3406 - val_accuracy: 0.8780
# Epoch 7/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2873 - accuracy: 0.8936 - val_loss: 0.3290 - val_accuracy: 0.8805
# Epoch 8/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2754 - accuracy: 0.8979 - val_loss: 0.3236 - val_accuracy: 0.8857
# Epoch 9/55
# 375/375 [==============================] - 2s 7ms/step - loss: 0.2645 - accuracy: 0.9017 - val_loss: 0.3239 - val_accuracy: 0.8854
# Epoch 10/55
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2519 - accuracy: 0.9072 - val_loss: 0.3137 - val_accuracy: 0.8875
# Epoch 11/55
# 375/375 [==============================] - 5s 13ms/step - loss: 0.2466 - accuracy: 0.9074 - val_loss: 0.3206 - val_accuracy: 0.8888
# Epoch 12/55
# 375/375 [==============================] - 3s 9ms/step - loss: 0.2352 - accuracy: 0.9118 - val_loss: 0.3148 - val_accuracy: 0.8874
# Epoch 13/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2287 - accuracy: 0.9146 - val_loss: 0.3306 - val_accuracy: 0.8853
# Epoch 14/55
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2206 - accuracy: 0.9183 - val_loss: 0.3183 - val_accuracy: 0.8893
# Epoch 15/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2136 - accuracy: 0.9198 - val_loss: 0.3220 - val_accuracy: 0.8907
# Epoch 16/55
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2044 - accuracy: 0.9225 - val_loss: 0.3198 - val_accuracy: 0.8913
# Epoch 17/55
# 375/375 [==============================] - 5s 13ms/step - loss: 0.2005 - accuracy: 0.9243 - val_loss: 0.3275 - val_accuracy: 0.8887
# Epoch 18/55
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1910 - accuracy: 0.9286 - val_loss: 0.3202 - val_accuracy: 0.8942
# Epoch 19/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1863 - accuracy: 0.9311 - val_loss: 0.3238 - val_accuracy: 0.8910
# Epoch 20/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1801 - accuracy: 0.9319 - val_loss: 0.3491 - val_accuracy: 0.8919
# Epoch 21/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1742 - accuracy: 0.9346 - val_loss: 0.3321 - val_accuracy: 0.8928
# Epoch 22/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1729 - accuracy: 0.9342 - val_loss: 0.3324 - val_accuracy: 0.8936
# Epoch 23/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1645 - accuracy: 0.9384 - val_loss: 0.3390 - val_accuracy: 0.8963
# Epoch 24/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1574 - accuracy: 0.9410 - val_loss: 0.3349 - val_accuracy: 0.8936
# Epoch 25/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1547 - accuracy: 0.9418 - val_loss: 0.3516 - val_accuracy: 0.8946
# Epoch 26/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1495 - accuracy: 0.9434 - val_loss: 0.3571 - val_accuracy: 0.8909
# Epoch 27/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1476 - accuracy: 0.9446 - val_loss: 0.3549 - val_accuracy: 0.8923
# Epoch 28/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1400 - accuracy: 0.9460 - val_loss: 0.3730 - val_accuracy: 0.8913
# Epoch 29/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1354 - accuracy: 0.9488 - val_loss: 0.3590 - val_accuracy: 0.8930
# Epoch 30/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1346 - accuracy: 0.9483 - val_loss: 0.3593 - val_accuracy: 0.8947
# Epoch 31/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1287 - accuracy: 0.9513 - val_loss: 0.3886 - val_accuracy: 0.8911
# Epoch 32/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1256 - accuracy: 0.9532 - val_loss: 0.3727 - val_accuracy: 0.8947
# Epoch 33/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1195 - accuracy: 0.9549 - val_loss: 0.3825 - val_accuracy: 0.8953
# Epoch 34/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1189 - accuracy: 0.9551 - val_loss: 0.3972 - val_accuracy: 0.8923
# Epoch 35/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1149 - accuracy: 0.9573 - val_loss: 0.4189 - val_accuracy: 0.8887
# Epoch 36/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1102 - accuracy: 0.9579 - val_loss: 0.4078 - val_accuracy: 0.8923
# Epoch 37/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1109 - accuracy: 0.9582 - val_loss: 0.4270 - val_accuracy: 0.8877
# Epoch 38/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1055 - accuracy: 0.9606 - val_loss: 0.4163 - val_accuracy: 0.8931
# Epoch 39/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1006 - accuracy: 0.9626 - val_loss: 0.4301 - val_accuracy: 0.8941
# Epoch 40/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1030 - accuracy: 0.9611 - val_loss: 0.4380 - val_accuracy: 0.8927
# Epoch 41/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0937 - accuracy: 0.9643 - val_loss: 0.4502 - val_accuracy: 0.8929
# Epoch 42/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0912 - accuracy: 0.9650 - val_loss: 0.4625 - val_accuracy: 0.8902
# Epoch 43/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0907 - accuracy: 0.9655 - val_loss: 0.4715 - val_accuracy: 0.8930
# Epoch 44/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0841 - accuracy: 0.9682 - val_loss: 0.4533 - val_accuracy: 0.8957
# Epoch 45/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0850 - accuracy: 0.9678 - val_loss: 0.4757 - val_accuracy: 0.8921
# Epoch 46/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0817 - accuracy: 0.9698 - val_loss: 0.4811 - val_accuracy: 0.8928
# Epoch 47/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0795 - accuracy: 0.9697 - val_loss: 0.5000 - val_accuracy: 0.8938
# Epoch 48/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0823 - accuracy: 0.9686 - val_loss: 0.5085 - val_accuracy: 0.8932
# Epoch 49/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0729 - accuracy: 0.9721 - val_loss: 0.4978 - val_accuracy: 0.8898
# Epoch 50/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0711 - accuracy: 0.9739 - val_loss: 0.5234 - val_accuracy: 0.8891
# Epoch 51/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0738 - accuracy: 0.9724 - val_loss: 0.5408 - val_accuracy: 0.8862
# Epoch 52/55
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0731 - accuracy: 0.9721 - val_loss: 0.5051 - val_accuracy: 0.8931
# Epoch 53/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0669 - accuracy: 0.9752 - val_loss: 0.5148 - val_accuracy: 0.8924
# Epoch 54/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0684 - accuracy: 0.9744 - val_loss: 0.5773 - val_accuracy: 0.8866
# Epoch 55/55
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0624 - accuracy: 0.9770 - val_loss: 0.5310 - val_accuracy: 0.8917
# Accuracy: 88.62%

# %%
predictions = model.predict(X_test)
predictions[0]
# Out:
# array([6.2173890e-12, 4.3915541e-14, 2.2417034e-14, 1.6411336e-16,
#        9.3991969e-13, 5.8703542e-10, 1.3367038e-15, 2.1271086e-07,
#        5.0927852e-18, 9.9999976e-01], dtype=float32)

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
  
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'
  
    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1]) 
    predicted_label = np.argmax(predictions_array)
 
    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, Y_test, test_images)
plt.show()
plt.subplot(1,2,2)
plot_value_array(i, predictions,  Y_test)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(final_model.history['accuracy'])
plt.plot(final_model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(final_model.history['loss'])
plt.plot(final_model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.show()
